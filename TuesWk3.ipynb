# %% [markdown]
# Quiz Questions.
#
#     Q1.What is intersectionality?
#     Q2.What is a posterior and a prior in the formula for probability?
#     Q3.What is a null hypothesis?
#     Q4.What is a confidence interval?
#     Q5.What is a p-value?
#     Q6.How do you tell which m.o.c.t. to use to fill missing values?

# %%
import numpy as np
import seaborn as sns
mean1, sd1 = 5, 3 # dist 1 
mean2, sd2 = 10, 2 # dist 2 
d1 = np.random.normal(mean1, sd1, 1000)
d2 = np.random.normal(mean2, sd2, 1000)
sns.histplot(data=(d1,d2))
# Out:
# <module 'seaborn' from '/opt/anaconda3/lib/python3.12/site-packages/seaborn/__init__.py'>
