# %% [markdown]
# #### Q1. Read about Monti-Hall Problem.
#
# #### Q2. What is a loss function ?
#
# #### Q3. Can you fetch data from a database?
#
# #### Q4. Steps on how to perform statistical modelling?
#
# #### Q5. Do house prices and time series problems.
#
# #### Q6. Independent vs dependent variables.
#
# #### Q7. What is data understanding?
#
# #### Q8. What does the term "multivariate statistics" stand for?
#
# #### Q9. (ASS) What is the difference between r0-squared and adjusted r-squared?
#
# #### Q10. What is feature importance?
#
# #### Q11. (wyc question) Which tests have we done that tell us the importance of features?
#
# #### Q12. z-score?
#
# #### Q13. f-statistic in ANOVA?
#
# #### Q14. Research on MSE, RMSE, MAE.
#
# #### Q15. What do model parameters tell us?
#
# #### Q16. What are the different types of correlations?
#
# #### Q17. What are the parameters of a neural network called?
#
# #### Q18. What is an intercept-only model?
#
# #### Q19. What does ESS and MSE stand for?
#
# #### Q20. How do you calculate degrees of freedom?
#
# #### Q21. How do you calculate f-statistic?
#
# #### Q22. What is the coeeficient of correlation?
#
# #### Q23. What percentage of a variation is explained by a model and how do you calculate this?
#
# #### Q24. What are the traits of a good r-squared value?
#
# #### Q25. Remember to do house prices..
#
# #### Q26. How do you use ols?
