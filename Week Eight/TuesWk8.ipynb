# %% [markdown]
# #### Q1. How do you fit a model using OLS?
#
# #### Q2. Creating an OLS table and performing an OLS fit.
#
# #### Q3. What is a confidence interval?
#
# #### Q4. What is an intercept-only model?
#
# #### Q5. Can you list thesteps for connecting to a database?
#
# #### Q6. What are the four assumptions we take when making a linear model?
#         linearity.
#         homoscedasticity.
#         independence.
#         normality.
#
# #### Q7. Three types of models are.
#
#     mean models
#     baseline models
#     restricted models.
#
# #### Q8. Do toy dataset example.
#
# #### Q9. How do you plot a scatterplot?
#
# #### Q10. Formula for f-statistic.
#
# F = MSE Model/MSE Residuals
#
# #### Q11. How do you get degrees of freedom of a model.
#
# #### Q12. How do you measure goodness of fit with r-squared?
#
# #### Q13. What are spurious correlations?
#
# #### Q14. Wht is the formula for adjusted r-squared?
#
# #### Q15. How do you do onehot encoding with get_dummies?
#
# #### Q16. Onehot encoder vs labelencoder?
#
# #### Q17. What are error-based metrics and give examples.
#
# #### Q18. How do you perform log transformations?
#
# #### Q19. What is a categorical variable?
#
# #### Q20. Figure out about multiple linear-regression models.
#
# #### Q21. When do you use label encoding and when do you use get dummies?
#
# #### Q22. List examples of loss/error based metrics.
#
# #### Q23. Why do we normalize data?
#
# #### Q24. What does MSE do?
#
# #### Q25. How do you know what evaluation matrix to use once you compare them?
#
# #### Q26. What is a dummy variable trap and how do you avoid it?
#
# #### Q27. What is VIF?
#
# #### Q28. High dimensionality vs Multicollinearity.
#
# #### Q29. How do you get the degrees of freedom for residuals?
#
# #### Q30. Uncentered vs centered r-squared?
#
# #### Q31. Create an Azure account for students.
#
# #### Q32. How do you use ssh?
#
# #### Q33. What do we use vim for?
#
# #### Q34. Install postgres and create a user.
