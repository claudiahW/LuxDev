# %% [markdown]
# # week 7 study questions plus assignments.
#
# #### Q1. ASS Question. There are 3 degrees of freedom in chi square test. name them.
#
# #### Q2. Article. Using your favorite  sport as a point of reference, tell us about the chi-square test. ie where and when do we use it?
#
# #### Q3.Read about technical article writing.
#
# #### Q4.What is aggregating data?
#
# #### Q5. What is categorical data and give an example.
#
# #### Q6. t-test, f-test, z-test.
#
# #### Q7. ASS Question. Read the superbowl question and submit as an assignment.
#
# #### Q8. p.s download all csv files in github repo ya notes.
#
# #### Q9. Do coin toss labs.
#
# #### Q10. What is the power divergent statistic?
#
# #### Q11. When do we say that there is no statistical significance?
#
# #### Q12. What does domain-specific problem stand for?
#
# #### Q13. What is a contingency table?
#
# #### Q14. Look for an A/B Testing datasets.
#
# #### Q15. What is EDA and what is its importance?
#
# #### Q16. What is a correlation coefficient?
#
# #### Q17. What is pearsons coefficient?
#
# #### Q18. What is a VIF?
#
# #### Q19. What is the direction/Magnitude of Multicollinearity?
#
# #### Q20. Difference between testing for independence and testing for goodness of fit.
#
# #### Q21. p-value vs z-score?
#
# #### Q22. What is conditional probability?
#
# #### Q23. (ASS)Article for week 7:Bayes Theorem , why we use it and where we use it?
#
# #### Q24.  Do beta fish labs.
#
# #### Q25. What is prior probability?
#
# #### Q26. Do houseprices index.
#
# #### Q27.
