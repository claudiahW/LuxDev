# %% [markdown]
# #### Q1. What is an indicator function?
#
# #### Q2. What is a one-sample k-s test?
#
# #### Q3. What is the formula for calculating PDF?
#
# #### Q4. What is VIF?
#
# #### Q5. What is relative importance by other ml models?
#
# #### Q6. How do you calculate ECDF?
#
# #### Q7. One-sample vs two-sample K-S tests.
#
# #### Q8. Define Null Hypothesis, Acceptance criteria and Rejection criteria.
#
# #### Q9. How do you set up a null hypothesis?
#
# #### Q10. What exactly is CDF and what does it affect?
#
# #### Q11. Why is k-s test usually done?
#
# #### Q12. Table value of d at significance level is given by?
#
# #### Q13. Where does normality come in in the K-S test?
#
# #### Q14. What does Central Limit Theorem (CLT) state?
#
# #### Q15. What does ANOVA stand for?
#
# #### Q16. What steps do we follow to perform anova?
#
# #### Q17. How is ANOVA important in feature engineering?
#
# #### Q18. How do you load data in anova?
#
# #### Q19. How do you generate an anova table?
#
# #### Q20. What is the formula for anova testing?
#
# #### Q21. What is an OLS Model?
#
# #### Q22. What is label encoding and how do you do it?
#
# #### Q23. Degrees of freedom vs DataFrame and how to distinguish between the two.(article self)
#
# #### Q24. What do residuals in anova stand for?
#
# #### Q25. How do you interpret an ANOVA table?
#
# #### Q26. What is alpha?
#
# #### Q27. What are residuals in ANOVA?
#
# #### Q28. What does unique_count represent/stand for?
#
# #### Q29. How do you identify unique elements?
#
# #### Q30. What is n-nearest residual ?
#
# #### Q31. What is an f-statistic and what is the formula for s-test?
#
# #### Q32. How do you interpret the f-statistic ?
#
# #### Q33. K-S test vs ANOVA?
