# %% [markdown]
# #### Q1. What is an indicator function?
#
# The indicator function of an event is a random variable that takes:
#
# value 1 when the event happens;
#
# value 0 when the event does not happen.
#
# Indicator functions are also called indicator random variables.
#
#
# #### Q2. What is a one-sample k-s test?
#
# The One-Sample Kolmogorov-Smirnov Test procedure compares the observed cumulative distribution function for a variable with a specified theoretical distribution, which may be normal, uniform, Poisson, or exponential.
#
# #### Q3. What is the formula for calculating PDF?
#
# f(x)=d/dx.F(x).
#
# #### Q4. What is VIF?
#
# VIF, or Variance Inflation Factor, is a statistical measure used in regression analysis to detect multicollinearity.It indicates how much the variance of a regression coefficient is inflated due to multicollinearity.
#
# #### Q5. What is relative importance by other ml models?
#
# In machine learning, relative importance (also known as feature importance) refers to a method of determining how much each input variable or feature contributes to a model's predictions. It quantifies the significance of individual features in the context of other features within a model, providing insights into which features are most impactful.
#
# #### Q6. How do you calculate ECDF?
#
# To calculate an Empirical Cumulative Distribution Function (ECDF), you first sort your data in ascending order. Then, for each unique value in your data, you determine the proportion of data points that are less than or equal to that value. Plot these proportions against their corresponding values to create the ECDF.
#
# #### Q7. One-sample vs two-sample K-S tests.
#
# The one-sample Kolmogorov-Smirnov (K-S) test compares a sample's distribution to a known theoretical distribution, while the two-sample K-S test compares the distributions of two samples to see if they are likely drawn from the same population. Both tests use the maximum distance between the cumulative distribution functions (CDFs) of the samples as a test statistic.
#
#
# #### Q8. Define Null Hypothesis, Acceptance criteria and Rejection criteria.
#
# The null hypothesis is a statement that there is no effect, no difference, or no relationship between variables. It serves as the default or starting assumption in statistical testing.
#
# Acceptance criteria refer to the conditions under which we fail to reject the null hypothesis. This means the observed data is consistent with the null hypothesis within an acceptable level of error.
#
# Typically, if the p-value > α (significance level), we accept or "fail to reject" the null hypothesis.
#
# Common significance levels: α = 0.05, 0.01, 0.10.
#
# Rejection criteria are the conditions under which we reject the null hypothesis in favor of the alternative hypothesis (H₁). This implies the data provides enough evidence that the null hypothesis is unlikely to be true.
#
# Typically, if the p-value ≤ α, we reject the null hypothesis.
#
# Alternatively, in a z-test or t-test, if the test statistic falls into the critical region (beyond critical value), we reject H₀.
#
#
# #### Q9. How do you set up a null hypothesis?
#
# 1. Identify the Research Question or Objective
# Start by determining what you're trying to investigate. This could involve comparing groups, testing an effect, or measuring a relationship.
#
# 2. Define the Population Parameters
# Identify what parameters (mean, proportion, variance, etc.) you're testing—usually using symbols like:
#
# μ (population mean)
#
# p (population proportion)
#
# σ² (population variance)
#
# 3. State the Null Hypothesis (H₀)
# Formulate a statement that assumes no effect, no difference, or status quo. It always includes an equality sign ( = , ≥ , or ≤).
#
# 4. Formulate the Alternative Hypothesis (H₁ or Ha)
# This is what you're trying to provide evidence for—typically the opposite of H₀.
#
#
#
#
# #### Q10. What exactly is CDF and what does it affect?
#
# The Cumulative Distribution Function (CDF) of a random variable describes the probability that the variable takes a value less than or equal to a certain value.
#
#
# #### Q11. Why is k-s test usually done?
#
# The Kolmogorov–Smirnov (K-S) test is usually done to compare distributions, and it serves two main purposes:
#
# 1. Test for goodness-of-fit:
#
# To determine whether a sample comes from a specific theoretical distribution (e.g., normal, exponential).
#
#
# 2. Compare two empirical distributions:
#
# To test whether two samples come from the same distribution.
#
#
#
# #### Q12. Table value of d at significance level is given by?
#
# #### Q13. Where does normality come in in the K-S test?
#
# #### Q14. What does Central Limit Theorem (CLT) state?
#
# #### Q15. What does ANOVA stand for?
#
# #### Q16. What steps do we follow to perform anova?
#
# #### Q17. How is ANOVA important in feature engineering?
#
# #### Q18. How do you load data in anova?
#
# #### Q19. How do you generate an anova table?
#
# #### Q20. What is the formula for anova testing?
#
# #### Q21. What is an OLS Model?
#
# #### Q22. What is label encoding and how do you do it?
#
# #### Q23. Degrees of freedom vs DataFrame and how to distinguish between the two.(article self)
#
# #### Q24. What do residuals in anova stand for?
#
# #### Q25. How do you interpret an ANOVA table?
#
# #### Q26. What is alpha?
#
# #### Q27. What are residuals in ANOVA?
#
# #### Q28. What does unique_count represent/stand for?
#
# #### Q29. How do you identify unique elements?
#
# #### Q30. What is n-nearest residual ?
#
# #### Q31. What is an f-statistic and what is the formula for s-test?
#
# #### Q32. How do you interpret the f-statistic ?
#
# #### Q33. K-S test vs ANOVA?
