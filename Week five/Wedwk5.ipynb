# %% [markdown]
# # assignment week five questions.(plus self assesment questions for myself.)
#
# ## Q1. What is alpha?
# In statistics, alpha (α) represents the significance level of a hypothesis test. It is the threshold probability used to decide whether to reject the null hypothesis (H₀).
#
# Alpha is the probability of making a Type I error — rejecting the null hypothesis when it is actually true.
#
#
#
#
# ## Q2. How do you conduct and visualize a t-test?
#
# ## Q3. What does alpha signify?
#
# ## Q4. What is a one-tail t-test?
#
# ## Q5. Step-by-step for hypothesis testing?
#
# ## Q6. What is the formula for a one-sample t-test?
#
# ## Q7. Why do we use degrees of freedom?
#
# ## Q8. Research on PDF, CDF and PMF and how to display/present them.
#
# ## Q9. How do you calculate p-value?
#
# ## Q10. What is a t-table?
#
# ## Q11. How do you calculate the critical value?
#
# ## Q12. What is a boundary?
#
# ## Q13. What is a one-sample t-test?
#
# ## Q14. What is an upper-tail probability?
#
# ## Q15. t-value vs t-test?
#
# ## Q16. t-test vs z-test?
#
# ## Q17. Steps to executing a t-test irrespective of if it is one-sample or two-sample.
#
#     1.Set up null and alternative hypothesis.
#     2.choose a significance level.
#     3.calculate the test-statistic.
#     4.Determine the critical t-value(find the rejection region)
#     5.compare t-value to critical t-value to determine if we reject or fail to reject the null hypothesis.
#
# ## Q18. Calculating p-value and t-value.
#
# ## Q19. Level of significance vs confidence level.
#
# ## Q20. Time series.
#
# ## Q21. t-value vs t-critical.
#
# ## Q22. Research more on data storytelling with powerbi.
#
# ## Q23. Do practice questions on hackerrank.
#
# ## Q24. Steps for the end-to-end machine learning model.
#
# ## Q25. When do use z-test and when do you use t-test?

# %% [markdown]
# # wednesday and thursday lessons's research questions.
#
#
# ## Q1. How do you calculate variance?
#
# ## Q2. What are the assumptions of the two-sample t-tests?
#
# ## Q3. Where do we use z-test and where do we use t-test?
#
# ## Q4. Two-sample t-test examples.
#
# ## Q5. How do you find f-statistic and t-critical?
#
#  Scipy is the library used for statistics.
#
# ## Q6. t-statistic vs t-critical value?
#
# when finding the p-value, you first check the pdf.
#
#
# ## Q7. How do you look at a t-table?
#
# ## Q8.Research on Resampling methods and monte carlo simulations amoing others.
#
# ## Q9. Feature importance and its importance in analysis. (ASS)
#
# ## Q10. When do we use hypothesis testing? Why?
#
# ## Q11.  Time series analysis week 5. (ASS).
#
# ## Q12. Do house prices linear regression.
#
# ## Q13. What is jackknifing and bootstrapping in terms of resampling methods?
#
# ## Q14. What is type I and type II error?
#
# ## Q15. What is Statistical Power?
#
# ## Q16. What is Welch's t-test?
#
# ## Q17.research more on  p-value, effec sizes, confidence levels.
#
# ## Q18. How and why do we use effect size in python?
#
# ## Q19. Research on how to do chi-square test?
#
# ## Q20. Calculating effect-size in python.
#
# ## Q21. How do you use scipy to calculate effect size?
#
# ## Q22. Parameter processing in python.
#
# ## Q23. What are the parameters that we use in a normal distribution curve?
#
# ## Q24. How to calculate standard deviation and variance.
#
# ## Q25. What are scipy objects?
#
# ## Q26. Where do we use PDF?
#
# ## Q27. How do you evaluate pdf?
#
# ## Q20. Do pdf practice on kaggle.
#
# ## Q21. Anova stands for Analysis Of Variance.
#
# ## Q22. What is a discrete random variable?
#
# ## Q23. Getting the difference between sample means.
#
# ## Q24. What is unstandardized effect size?
#
# ## Q25. What is the relative difference and how do you calculate it?
#
# ## Q26. What is an overlap threshhold?
#
# ## Q27. Article for week five another one.
#
#                 write about classification matrices why and when we use them and give examples.
