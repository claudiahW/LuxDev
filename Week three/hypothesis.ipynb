# %%
import scipy.stats as stats , numpy as np, matplotlib.pyplot as plt 
from math import sqrt

x_bar = 103 #sample mean 
n =40 # number of students 
sigma = 16 # sd of population 
mu = 100 # population mean 

z = (x_bar - mu) / (sigma / sqrt(n))

z
# Out:
# 1.1858541225631423

# %%
# plotting the z-value on a standard normal distribution 

plt.style.use('seaborn-v0_8-whitegrid')
plt.fill_between(x=np.arange(-4,1.19,0.01),
                  y1= stats.norm.pdf(np.arange(-4,1.19,0.01)) ,
                 facecolor='red',
                 alpha=0.35,
                 label= 'Area below z-statistic'
                 )
plt.fill_between(x=np.arange(1.19,4,0.01), 
                 y1= stats.norm.pdf(np.arange(1.19,4,0.01)) ,
                 facecolor='blue',
                 alpha=0.35, 
                 label= 'Area above z-statistic')

plt.legend()
plt.title('Z-Value on a Standard Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Z-Value on a Standard Normal Distribution')

# %% [markdown]
# # calculating p-value

# %%
stats.norm.cdf(z)
# Out:
# 0.8821600432854813

# %%
pval = 1 - stats.norm.cdf(z)
pval
# Out:
# 0.11783995671451875

# %%
# Probabilities up to z-score of 1.5
print(stats.norm.cdf(1.5))
# Out:
# 0.9331927987311419

# %%
# Probabilities greater than z-score of 1.34
print (1-stats.norm.cdf(1.34))
# Out:
# 0.09012267246445238

# %%
# Z-table in Python 
import scipy.stats as stats

# Probabilities up to z-score of 1.5
print(stats.norm.cdf(1.5))

# Probabilities greater than z-score of 1.34
print (1-stats.norm.cdf(1.34))
# Out:
# 0.9331927987311419
# 0.09012267246445238
