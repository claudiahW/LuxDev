# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df =pd.read_csv(r'/Users/apple/Documents/LuxHq/train_data_cross-sell.csv', encoding='latin1')

unique_counts = df.nunique()

columns_to_encode = unique_counts[unique_counts <= 2].index.tolist()

le = LabelEncoder()

for col in columns_to_encode:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#          ÿid  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831       1        Monday, March 7, 1977                1
# 1  373583351       1    Sunday, December 29, 2002                1
# 2  933163655       0     Tuesday, August 23, 1994                1
# 3  698942186       0  Thursday, November 18, 1999                1
# 4  515109822       1  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  \
# 0                         2020               1           38294
# 1                         2020               0           28619
# 2                         2011               0           27496
# 3                         2020               1            2630
# 4                         2015               1           23367
#
#        Agent_name       Life_policy_start_date  Response
# 0   Jomo Kenyatta  Thursday, December 21, 2023         1
# 1  Obiero Ochieng     Wednesday, June 28, 2023         0
# 2  Obiero Ochieng   Saturday, December 9, 2023         0
# 3  Gitonga Mwangi       Tuesday, July 25, 2023         0
# 4  Obiero Ochieng       Saturday, May 13, 2023         0
