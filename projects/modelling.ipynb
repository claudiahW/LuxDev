# %% [markdown]
# # Plotting Independent and Dependent Variables

# %%
# load necessary imports and packages 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# https://www.statsmodels.org/devel/generated/statsmodels.regression.linear_model.OLS.html
import statsmodels.api as sm

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\advertising.csv", index_col=0) 
data.plot(x="TV", y="sales", kind="scatter"); # scatter plot of TV vs Sales

# %%
results = sm.OLS(data["sales"], sm.add_constant(data[["TV"]])).fit()
results.params
# Out:
# const    7.032594
# TV       0.047537
# dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots();
data.plot(x="TV", y="sales", kind="scatter", ax=ax)

# set up line data representing linear regression model
x = np.linspace(data["TV"].min(), data["TV"].max())
y = x * results.params["TV"] + results.params["const"]

# plot model on the same axes as the data
ax.plot(x, y, color="black");

# %%
results.pvalues
# Out:
# const    1.406300e-35
# TV       1.467390e-42
# dtype: float64
